# %% [markdown]
# 1.  Find the value of T(2) for the recurrence relation T(n) = 3T(n-1) + 12n, given that T(0)=5.
#
#
# Ans=
# We are given the recurrence relation:
#
# 𝑇
# (
# 𝑛
# )
# =
# 3
# 𝑇
# (
# 𝑛
# −
# 1
# )
# +
# 12
# 𝑛
# T(n)=3T(n−1)+12n
#
# with the base case:
#
# 𝑇
# (
# 0
# )
# =
# 5
# T(0)=5
# We need to find
# 𝑇
# (
# 2
# )
# T(2).
#
# Step 1: Compute
# 𝑇
# (
# 1
# )
# T(1)
#
# Using the recurrence relation:
#
# 𝑇
# (
# 1
# )
# =
# 3
# 𝑇
# (
# 0
# )
# +
# 12
# (
# 1
# )
# T(1)=3T(0)+12(1)
#
# Substituting
# 𝑇
# (
# 0
# )
# =
# 5
# T(0)=5:
#
# 𝑇
# (
# 1
# )
# =
# 3
# (
# 5
# )
# +
# 12
# (
# 1
# )
# =
# 15
# +
# 12
# =
# 27
# T(1)=3(5)+12(1)=15+12=27
#
# Step 2: Compute
# 𝑇
# (
# 2
# )
# T(2)
#
# Now, using the recurrence relation again:
#
# 𝑇
# (
# 2
# )
# =
# 3
# 𝑇
# (
# 1
# )
# +
# 12
# (
# 2
# )
# T(2)=3T(1)+12(2)
#
# Substituting
# 𝑇
# (
# 1
# )
# =
# 27
# T(1)=27:
#
# 𝑇
# (
# 2
# )
# =
# 3
# (
# 27
# )
# +
# 12
# (
# 2
# )
# =
# 81
# +
# 24
# =
# 105
# T(2)=3(27)+12(2)=81+24=105
#
#
# Final Answer: 105

# %% [markdown]
# 2. Given a recurrence relation, solve it using the substitution method:
#
# a. T(n) = T(n-1) + c
#
# b. T(n) = 2T(n/2) + n
#
# c. T(n) = 2T(n/2) + c
#
# d. T(n) = T(n/2) + c
#
# Ans==
#
# 1.
# (a)
# 𝑇
# (
# 𝑛
# )
# =
# 𝑇
# (
# 𝑛
# −
# 1
# )+
# 𝑐
# T(n)=T(n−1)+c
#
# This is a simple arithmetic recurrence.
#
# Expanding the recurrence:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑇
# (
# 𝑛
# −
# 1
# )
# +
# 𝑐
# T(n)=T(n−1)+c
# 𝑇
# (
# 𝑛
# −
# 1
# )
# =
# 𝑇
# (
# 𝑛
# −
# 2
# )
# +
# 𝑐
# T(n−1)=T(n−2)+c
# 𝑇
# (
# 𝑛
# −
# 2
# )
# =
# 𝑇
# (
# 𝑛
# −
# 3
# )
# +
# 𝑐
# T(n−2)=T(n−3)+c
#
# Continuing this process, after
# 𝑘
# k steps:
#
# 𝑇
# (
# 𝑛
# −
# 𝑘
# )
# =
# 𝑇
# (
# 𝑛
# −
# 𝑘
# −
# 1
# )
# +
# 𝑐
# T(n−k)=T(n−k−1)+c
#
# When
# 𝑘
# =
# 𝑛
# k=n, we reach the base case
# 𝑇
# (
# 0
# )
# T(0):
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑇
# (
# 0
# )
# +
# 𝑛
# 𝑐
# T(n)=T(0)+nc
#
# Final Solution:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑇
# (
# 0
# )
# +
# 𝑛
# 𝑐
# T(n)=T(0)+nc

# %% [markdown]
# 2. (b)
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑇
# (
# 𝑛
# /
# 2
# )
# +
# 𝑛
# T(n)=2T(n/2)+n
# This is a divide-and-conquer recurrence.
#
# Expanding the recurrence:
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑇
# (
# 𝑛
# /
# 2
# )
# +
# 𝑛
# T(n)=2T(n/2)+n
# 𝑇
# (
# 𝑛
# /
# 2
# )
# =
# 2
# 𝑇
# (
# 𝑛
# /
# 4
# )
# +
# 𝑛
# /
# 2
# T(n/2)=2T(n/4)+n/2
#
# Substituting this into the first equation:
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# [
# 2
# 𝑇
# (
# 𝑛
# /
# 4
# )
# +
# 𝑛
# /
# 2
# ]
# +
# 𝑛
# T(n)=2[2T(n/4)+n/2]+n
# =
# 4
# 𝑇
# (
# 𝑛
# /
# 4
# )
# +
# 2
# (
# 𝑛
# /
# 2
# )
# +
# 𝑛
# =4T(n/4)+2(n/2)+n
# =
# 4
# 𝑇
# (
# 𝑛
# /
# 4
# )
# +
# 𝑛
# +
# 𝑛
# =4T(n/4)+n+n
# =
# 4
# 𝑇
# (
# 𝑛
# /
# 4
# )
# +
# 2
# 𝑛
# =4T(n/4)+2n
# Expanding further:
#
# 𝑇
# (
# 𝑛
# )
# =
# 8
# 𝑇
# (
# 𝑛
# /
# 8
# )
# +
# 3
# 𝑛
# T(n)=8T(n/8)+3n
# After
# 𝑘
# k steps, we get:
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑘
# 𝑇
# (
# 𝑛
# /
# 2
# 𝑘
# )
# +
# 𝑘
# 𝑛
# T(n)=2
# k
#  T(n/2
# k
#  )+kn
#
# Since the recurrence reduces the problem size by half each time, we set
#
# 𝑛
# /
# 2
# 𝑘
# =
# 1
# n/2
# k
#  =1, so
# 𝑘
# =
# log
# ⁡
# 2
# 𝑛
# k=log
# 2
# ​
#  n.
#
# Substituting
# 𝑘
# =
# log
# ⁡
# 2
# 𝑛
# k=log
# 2
# ​
#  n:
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# log
# ⁡
# 2
# 𝑛
# 𝑇
# (
# 1
# )
# +
# 𝑛
# log
# ⁡
# 2
# 𝑛
# T(n)=2
# log
# 2
# ​
#  n
#  T(1)+nlog
# 2
# ​
#  n
# Since
# 2
# log
# ⁡
# 2
# 𝑛
# =
# 𝑛
# 2
# log
# 2
# ​
#  n
#  =n, we get:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑛
# 𝑇
# (
# 1
# )
# +
# 𝑛
# log
# ⁡
# 2
# 𝑛
# T(n)=nT(1)+nlog
# 2
# ​
#  n
# If
# 𝑇
# (
# 1
# )
# T(1) is a constant
# 𝑐
# ′
# c
# ′
#  , then:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑂
# (
# 𝑛
# log
# ⁡
# 𝑛
# )
# T(n)=O(nlogn)

# %% [markdown]
# 3. (c)
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑇
# (
# 𝑛
# /
# 2
# )
# +
# 𝑐
# T(n)=2T(n/2)+c
#
# This is another divide-and-conquer recurrence, but with a constant term.
#
# Expanding the recurrence:
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑇
# (
# 𝑛
# /
# 2
# )
# +
# 𝑐
# T(n)=2T(n/2)+c
# 𝑇
# (
# 𝑛
# /
# 2
# )
# =
# 2
# 𝑇
# (
# 𝑛
# /
# 4
# )
# +
# 𝑐
# T(n/2)=2T(n/4)+c
#
# Substituting:
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# [
# 2
# 𝑇
# (
# 𝑛
# /
# 4
# )
# +
# 𝑐
# ]
# +
# 𝑐
# T(n)=2[2T(n/4)+c]+c
# =
# 4
# 𝑇
# (
# 𝑛
# /
# 4
# )
# +
# 2
# 𝑐
# +
# 𝑐
# =4T(n/4)+2c+c
# =
# 4
# 𝑇
# (
# 𝑛
# /
# 4
# )
# +
# 3
# 𝑐
# =4T(n/4)+3c
#
# Expanding further:
#
# 𝑇
# (
# 𝑛
# )
# =
# 8
# 𝑇
# (
# 𝑛
# /
# 8
# )
# +
# 7
# 𝑐
# T(n)=8T(n/8)+7c
# After
# 𝑘
# k steps:
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑘
# 𝑇
# (
# 𝑛
# /
# 2
# 𝑘
# )
# +
# (
# 2
# 𝑘
# −
# 1
# )
# 𝑐
# T(n)=2
# k
#  T(n/2
# k
#  )+(2
# k
#  −1)c
# Setting
# 𝑛
# /
# 2
# 𝑘
# =
# 1
# n/2
# k
#  =1, so
# 𝑘
# =
# log
# ⁡
# 2
# 𝑛
# k=log
# 2
# ​
#  n:
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# log
# ⁡
# 2
# 𝑛
# 𝑇
# (
# 1
# )
# +
# (
# 2
# log
# ⁡
# 2
# 𝑛
# −
# 1
# )
# 𝑐
# T(n)=2
# log
# 2
# ​
#  n
#  T(1)+(2
# log
# 2
# ​
#  n
#  −1)c
# Since
# 2
# log
# ⁡
# 2
# 𝑛
# =
# 𝑛
# 2
# log
# 2
# ​
#  n
#  =n, we get:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑛
# 𝑇
# (
# 1
# )
# +
# (
# 𝑛
# −
# 1
# )
# 𝑐
# T(n)=nT(1)+(n−1)c
#
# For constant
# 𝑇
# (
# 1
# )
# T(1), this simplifies to:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑂
# (
# 𝑛
# )
# T(n)=O(n)

# %% [markdown]
# 4. (d)
# 𝑇
# (
# 𝑛
# )
# =
# 𝑇
# (
# 𝑛
# /
# 2
# )
# +
# 𝑐
# T(n)=T(n/2)+c
#
# This recurrence reduces the problem size by half in each step.
#
# Expanding the recurrence:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑇
# (
# 𝑛
# /
# 2
# )
# +
# 𝑐
# T(n)=T(n/2)+c
# 𝑇
# (
# 𝑛
# /
# 2
# )
# =
# 𝑇
# (
# 𝑛
# /
# 4
# )
# +
# 𝑐
# T(n/2)=T(n/4)+c
#
# Substituting:
#
# 𝑇
# (
# 𝑛
# )
# =
# [
# 𝑇
# (
# 𝑛
# /
# 4
# )
# +
# 𝑐
# ]
# +
# 𝑐
# T(n)=[T(n/4)+c]+c
# =
# 𝑇
# (
# 𝑛
# /
# 4
# )
# +
# 2
# 𝑐
# =T(n/4)+2c
#
# Expanding further:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑇
# (
# 𝑛
# /
# 8
# )
# +
# 3
# 𝑐
# T(n)=T(n/8)+3c
# After
# 𝑘
# k steps:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑇
# (
# 𝑛
# /
# 2
# 𝑘
# )
# +
# 𝑘
# 𝑐
# T(n)=T(n/2
# k
#  )+kc
# Setting
# 𝑛
# /
# 2
# 𝑘
# =
# 1
# n/2
# k
#  =1, so
# 𝑘
# =
# log
# ⁡
# 2
# 𝑛
# k=log
# 2
# ​
#  n:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑇
# (
# 1
# )
# +
# 𝑐
# log
# ⁡
# 2
# 𝑛
# T(n)=T(1)+clog
# 2
# ​
#  n
# For constant
# 𝑇
# (
# 1
# )
# T(1), we get:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑂
# (
# log
# ⁡
# 𝑛
# )
# T(n)=O(logn)

# %% [markdown]
# 3. Given a recurrence relation, solve it using the recursive tree approach:
#
# a. T(n) = 2T(n-1) +1
#
#
#
# 1. (a)
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑇
# (
# 𝑛
# −
# 1
# )
# +
# 1
# T(n)=2T(n−1)+1
#
# Expanding the recurrence (recursive tree method)
#
# Expanding the recurrence step by step:
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑇
# (
# 𝑛
# −
# 1
# )
# +
# 1
# T(n)=2T(n−1)+1
# 𝑇
# (
# 𝑛
# −
# 1
# )
# =
# 2
# 𝑇
# (
# 𝑛
# −
# 2
# )
# +
# 1
# T(n−1)=2T(n−2)+1
#
# Substituting
#
# 𝑇
# (
# 𝑛
# −
# 1
# )
# T(n−1) into
# 𝑇
# (
# 𝑛
# )
# T(n):
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# [
# 2
# 𝑇
# (
# 𝑛
# −
# 2
# )
# +
# 1
# ]
# +
# 1
# T(n)=2[2T(n−2)+1]+1
# =
# 4
# 𝑇
# (
# 𝑛
# −
# 2
# )
# +
# 2
# +
# 1
# =
# 4
# 𝑇
# (
# 𝑛
# −
# 2
# )
# +
# 3
# =4T(n−2)+2+1=4T(n−2)+3
# Expanding further:
#
# 𝑇
# (
# 𝑛
# −
# 2
# )
# =
# 2
# 𝑇
# (
# 𝑛
# −
# 3
# )
# +
# 1
# T(n−2)=2T(n−3)+1
#
# Substituting:
#
# 𝑇
# (
# 𝑛
# )
# =
# 8
# 𝑇
# (
# 𝑛
# −
# 3
# )
# +
# 7
# T(n)=8T(n−3)+7
# After
# 𝑘
# k steps:
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑘
# 𝑇
# (
# 𝑛
# −
# 𝑘
# )
# +
# (
# 2
# 𝑘
# −
# 1
# )
# T(n)=2
# k
#  T(n−k)+(2
# k
#  −1)
# Finding
# 𝑘
# k
# We reach the base case
# 𝑇
# (
# 0
# )
# T(0) when
# 𝑘
# =
# 𝑛
# k=n:
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑛
# 𝑇
# (
# 0
# )
# +
# (
# 2
# 𝑛
# −
# 1
# )
# T(n)=2
# n
#  T(0)+(2
# n
#  −1)
# Assuming
# 𝑇
# (
# 0
# )
# =
# 𝑐
# T(0)=c:
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑛
# 𝑐
# +
# (
# 2
# 𝑛
# −
# 1
# )
# T(n)=2
# n
#  c+(2
# n
#  −1)
# For large
# 𝑛
# n, the dominant term is
# 2
# 𝑛
# 2
# n
#  , so:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑂
# (
# 2
# 𝑛
# )
# T(n)=O(2
# n
#  )

# %% [markdown]
# b. T(n) = 2T(n/2) + n
#
# Ans==(b)
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑇
# (
# 𝑛
# /
# 2
# )
# +
# 𝑛
# T(n)=2T(n/2)+n
#
# This is a divide-and-conquer recurrence.
#
# Expanding the recurrence (recursive tree method)
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑇
# (
# 𝑛
# /
# 2
# )
# +
# 𝑛
# T(n)=2T(n/2)+n
#
# Expanding further:
#
# 𝑇
# (
# 𝑛
# /
# 2
# )
# =
# 2
# 𝑇
# (
# 𝑛
# /
# 4
# )
# +
# 𝑛
# /
# 2
# T(n/2)=2T(n/4)+n/2
#
# Substituting:
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# [
# 2
# 𝑇
# (
# 𝑛
# /
# 4
# )
# +
# 𝑛
# /
# 2
# ]
# +
# 𝑛
# T(n)=2[2T(n/4)+n/2]+n
# =
# 4
# 𝑇
# (
# 𝑛
# /
# 4
# )
# +
# 2
# (
# 𝑛
# /
# 2
# )
# +
# 𝑛
# =4T(n/4)+2(n/2)+n
# =
# 4
# 𝑇
# (
# 𝑛
# /
# 4
# )
# +
# 2
# 𝑛
# =4T(n/4)+2n
# Expanding further:
#
# 𝑇
# (
# 𝑛
# )
# =
# 8
# 𝑇
# (
# 𝑛
# /
# 8
# )
# +
# 3
# 𝑛
# T(n)=8T(n/8)+3n
# Continuing this expansion, after
# 𝑘
# k levels:
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑘
# 𝑇
# (
# 𝑛
# /
# 2
# 𝑘
# )
# +
# 𝑘
# 𝑛
# T(n)=2
# k
#  T(n/2
# k
#  )+kn
# Finding
# 𝑘
# k
# We reach the base case when
# 𝑛
# /
# 2
# 𝑘
# =
# 1
# n/2
# k
#  =1, so:
#
# 2
# 𝑘
# =
# 𝑛
# ⇒
# 𝑘
# =
# log
# ⁡
# 2
# 𝑛
# 2
# k
#  =n⇒k=log
# 2
# ​
#  n
# Substituting
# 𝑘
# =
# log
# ⁡
# 2
# 𝑛
# k=log
# 2
# ​
#  n:
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# log
# ⁡
# 2
# 𝑛
# 𝑇
# (
# 1
# )
# +
# 𝑛
# log
# ⁡
# 2
# 𝑛
# T(n)=2
# log
# 2
# ​
#  n
#  T(1)+nlog
# 2
# ​
#  n
# Since
# 2
# log
# ⁡
# 2
# 𝑛
# =
# 𝑛
# 2
# log
# 2
# ​
#  n
#  =n, we get:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑛
# 𝑇
# (
# 1
# )
# +
# 𝑛
# log
# ⁡
# 2
# 𝑛
# T(n)=nT(1)+nlog
# 2
# ​
#  n
# For constant
# 𝑇
# (
# 1
# )
# T(1), this simplifies to:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑂
# (
# 𝑛
# log
# ⁡
# 𝑛
# )
# T(n)=O(nlogn)
